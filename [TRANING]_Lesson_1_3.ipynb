# %% [markdown]
# <a href="https://colab.research.google.com/github/kurniaw/5m-data-1.2-intro-database/blob/main/%5BTRANING%5D_Lesson_1_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# This is testing from google colab.
